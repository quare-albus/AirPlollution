# %% [markdown]
# <a href="https://colab.research.google.com/github/quare-albus/AirPlollution/blob/main/Preliminary_PM2_5vAOD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This pilot project will look into only the January 2025 HOURLY CPCB data of shivaji nagar

# %%
import pandas as pd

CPCB = pd.read_csv("//content//Raw_data_1Hr_2025_site_5409_Revenue_Colony-Shivajinagar_Pune_IITM_1Hr.csv")
CPCB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            8760 non-null   object
#  1   PM2.5 (µg/m³)        6633 non-null   float64
#  2   PM10 (µg/m³)         6908 non-null   float64
#  3   NO (µg/m³)           6707 non-null   float64
#  4   NO2 (µg/m³)          6721 non-null   float64
#  5   NOx (ppb)            6716 non-null   float64
#  6   NH3 (µg/m³)          0 non-null      float64
#  7   SO2 (µg/m³)          6770 non-null   float64
#  8   CO (mg/m³)           7073 non-null   float64
#  9   Ozone (µg/m³)        7253 non-null   float64
#  10  Benzene (µg/m³)      7440 non-null   float64
#  11  Toluene (µg/m³)      7426 non-null   float64
#  12  Xylene (µg/m³)       6458 non-null   float64
#  13  O Xylene (µg/m³)     0 non-null      float64
#  14  Eth-Benzene (µg/m³)  7324 non-null   float64
# ...

# %%
CPCB['Timestamp'] = pd.to_datetime(CPCB['Timestamp'])
CPCB.replace(['NA','--','null'], pd.NA, inplace=True)
CPCB.dropna()
CPCB = CPCB.drop_duplicates()
CPCB.describe()
CPCB.columns = CPCB.columns.str.lower()
CPCB.columns = CPCB.columns.str.replace(".","_")
